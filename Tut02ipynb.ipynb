# %% [markdown]
# <a href="https://colab.research.google.com/github/KeshUdana/MaxEstates/blob/main/Tut02ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas

# %%
import pandas as pd

data_frame=pd.read_csv("/content/drive/MyDrive/Mall_Customers.csv")
list(data_frame.columns)
data_frame.info()
data_frame.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Gender                  200 non-null    object
#  2   Age                     197 non-null    float64
#  3   Annual Income (k$)      198 non-null    float64
#  4   Spending Score (1-100)  199 non-null    float64
# dtypes: float64(3), int64(1), object(1)
# memory usage: 7.9+ KB
#    CustomerID  Gender   Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male  19.0                15.0                     NaN
# 1           2    Male   NaN                15.0                    81.0
# 2           3  Female  20.0                16.0                     6.0
# 3           4  Female  23.0                 NaN                    77.0
# 4           5  Female   NaN                 NaN                    40.0
# ...

# %%
data_frame.describe()
# Out:
#        CustomerID         Age  Annual Income (k$)  Spending Score (1-100)
# count  200.000000  197.000000          198.000000              199.000000
# mean   100.500000   39.000000           61.005051               50.256281
# std     57.879185   14.002915           26.017857               25.876350
# min      1.000000   18.000000           15.000000                1.000000
# 25%     50.750000   29.000000           42.250000               34.500000
# 50%    100.500000   36.000000           62.000000               50.000000
# 75%    150.250000   49.000000           78.000000               73.000000
# max    200.000000   70.000000          137.000000               99.000000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_1['CustomerID'].plot(kind='hist', bins=20, title='CustomerID')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# ...

# %%
data_frame.describe(include='object')
# Out:
#         Gender
# count      200
# unique       2
# top     Female
# freq       112
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_0.groupby('Gender').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
data_frame.isnull().sum()
print("Number of null values in each column")
# Out:
# CustomerID                0
# Gender                    0
# Age                       3
# Annual Income (k$)        2
# Spending Score (1-100)    1
# dtype: int64

# %%
data_frame.isna().sum()/len(data_frame)*100
# Out:
# CustomerID                0.0
# Gender                    0.0
# Age                       1.5
# Annual Income (k$)        1.0
# Spending Score (1-100)    0.5
# dtype: float64
